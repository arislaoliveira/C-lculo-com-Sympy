# %% [markdown]
# <a href="https://colab.research.google.com/github/arislaoliveira/calculo-sympy/blob/main/Esbo%C3%A7ando_Gr%C3%A1ficos_de_Fun%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *
# %matplotlib inline

# %%
from sympy.plotting import *

# %%
x = Symbol('x')

# %%
plot(x**2)

# %%
plot(x**2, (x,-2,2))

# %%
plot(x**2, 5*sin(x), (x,-2,2), title = 'Gráfico', xlabel = 'X', ylabel = 'Y', legend=true)
